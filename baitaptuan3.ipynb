# %%
#w3a2
a=1
b=0
b=b^a
a=b^a
print(a)
print(b)
# Out:
# 0
# 1

# %%
#w3a3
#kiem tra xem 1 so co phai luy thua cua 2 hay kh
n=int(input())
def so(a):
  for i in range(0,a+1):
    if 2**i==a:
      return True
  return False
if so(n):
  print(n,"la luy thua cua 2")
else:
  print("day kh phai luy thua cua 2")
# Out:
# 8 la luy thua cua 2

# %%
#w3a4
m=float(input())
n=float(input())
b=m//n
print(b)
# Out:
# 1.0

# %%
#w3a5
m=float(input())
n=float(input())
b=m//n
a=b+1
print(a)
# Out:
# 2.0

# %%
#w3a6
x=int(input())
if x%2==0:
  print("even")
else:
  print("odd")
# Out:
# even

# %%
#w3a7
a,b=map(int,input().split())
if a<0 and b<0:
  print("yes")
else:
  print("no")
# Out:
# no

# %%
#w3a8
a=input()
b=input()
if len(a)>len(b):
  print(True)
else:
  print(False)
# Out:
# False

# %%
#w3a9
a,b,c=map(int,input().split())
if (a+b>c or a+c>b or b+c>a) and a>0 and b>0 and c>0:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
#w3a10
a,b,c,d=map(int,input().split())
max=a
if b>max:
  max=b
if d>max:
  max=d
if c>max:
  max =c
print(max)
# Out:
# 9

# %%
#w3a11
a,b,c=map(int,input().split())
if (a+b>c or a+c>b or b+c>a) and a>0 and b>0 and c>0:
  if a==b==c:
    print("day la tam giac deu")
  elif a==b!=c or a==c!=b or b==c!=a:
    print("day la tam giac can")
  else:
    print("day la tam giac thuong")
else:
  print("day kh tao nen 1 tam giac")
# Out:
# day la tam giac deu

# %%
#w3a12
while True:
  try:
    n=int(input())
    if n>0:
      break
    else:
      print("vui long nhap so nguyen duong")
  except ValueError:
    print("vui long nhap so nguyen")
if (n%4==0 and n%100!=0) or n%400==0:
  print("nam do la nam nhuan")
else:
  print("nam do kh phai nam nhuan")
# Out:
# nam do kh phai nam nhuan

# %%
#w3a14
#giai pt ax+b=0
a=int(input())
b=int(input())
if a==0 and b==0:
  print("pt tren vo so nghiem")
elif a==0 and b!=0:
  print("pt tren vo nghiem")
else:
  x=-b/a
  print(round(x,2))
# Out:
# -1.25

# %%
#w3a15
diemtb=float(input())
if diemtb<10.0:
  if diemtb>8.0:
    print("gioi")
  elif diemtb<8.0 and diemtb>=6.5:
    print("kha")
  elif diemtb>5.0 and diemtb<6.5:
    print("trung binh")
  else:
    print("yeu")
# Out:
# gioi

# %%
#w3a16
n=float(input())
a=int(n)
if n-a>=0.5:
  a+=1
  print(a)
else:
  print(a)
# Out:
# 9

# %%
#w3a17
a,b,c,d=map(float,input().split())
x=b/a
if c==b*x and d==c*x:
  print("co tao thanh 1 cap so nhan")
else:
  print("kh tao than 1 cap so nhan")
# Out:
# kh tao than 1 cap so nhan
